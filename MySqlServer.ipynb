-- %% [markdown]
-- # [MtEntretenimiento]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [MtEntretenimiento]    Script Date: 20/05/2025 09:48:06 p. m. ******/
CREATE DATABASE [MtEntretenimiento]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'MtEntretenimiento', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\MtEntretenimiento.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'MtEntretenimiento_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\MtEntretenimiento_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [MtEntretenimiento] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [MtEntretenimiento].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [MtEntretenimiento] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET ARITHABORT OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [MtEntretenimiento] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [MtEntretenimiento] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET  ENABLE_BROKER 
GO
ALTER DATABASE [MtEntretenimiento] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [MtEntretenimiento] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET RECOVERY FULL 
GO
ALTER DATABASE [MtEntretenimiento] SET  MULTI_USER 
GO
ALTER DATABASE [MtEntretenimiento] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [MtEntretenimiento] SET DB_CHAINING OFF 
GO
ALTER DATABASE [MtEntretenimiento] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [MtEntretenimiento] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [MtEntretenimiento] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [MtEntretenimiento] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'MtEntretenimiento', N'ON'
GO
ALTER DATABASE [MtEntretenimiento] SET QUERY_STORE = ON
GO
ALTER DATABASE [MtEntretenimiento] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Favorites]

-- %%
USE [MtEntretenimiento]
GO

-- %%
/****** Object:  Table [dbo].[Favorites]    Script Date: 20/05/2025 09:48:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Favorites](
	[UserId] [int] NOT NULL,
	[MovieId] [int] NOT NULL,
	[FavoriteAt] [datetime2](7) NOT NULL,
 CONSTRAINT [PK_Favorites] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC,
	[MovieId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Movies]

-- %%
/****** Object:  Table [dbo].[Movies]    Script Date: 20/05/2025 09:48:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Movies](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Title] [nvarchar](200) NOT NULL,
	[Overview] [nvarchar](max) NULL,
	[PosterPath] [nvarchar](500) NULL,
	[ReleaseDate] [date] NULL,
	[VoteAverage] [decimal](3, 1) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MTData]

-- %%
/****** Object:  Table [dbo].[MTData]    Script Date: 20/05/2025 09:48:07 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MTData](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[Username] [nvarchar](100) NOT NULL,
	[PasswordHash] [varbinary](64) NULL,
	[CreateDate] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Favorites__Favor__4222D4EF]

-- %%
ALTER TABLE [dbo].[Favorites] ADD  DEFAULT (sysutcdatetime()) FOR [FavoriteAt]
GO

-- %% [markdown]
-- # [DF__Users__CreateDat__38996AB5]

-- %%
ALTER TABLE [dbo].[MTData] ADD  DEFAULT (sysutcdatetime()) FOR [CreateDate]
GO

-- %% [markdown]
-- # [FK_Favorites_Movie]

-- %%
ALTER TABLE [dbo].[Favorites]  WITH CHECK ADD  CONSTRAINT [FK_Favorites_Movie] FOREIGN KEY([MovieId])
REFERENCES [dbo].[Movies] ([id])
GO
ALTER TABLE [dbo].[Favorites] CHECK CONSTRAINT [FK_Favorites_Movie]
GO

-- %% [markdown]
-- # [FK_Favorites_User]

-- %%
ALTER TABLE [dbo].[Favorites]  WITH CHECK ADD  CONSTRAINT [FK_Favorites_User] FOREIGN KEY([UserId])
REFERENCES [dbo].[MTData] ([id])
GO
ALTER TABLE [dbo].[Favorites] CHECK CONSTRAINT [FK_Favorites_User]
GO

-- %% [markdown]
-- # [MtEntretenimiento]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [MtEntretenimiento] SET  READ_WRITE 
GO
